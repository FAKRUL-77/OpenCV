# %% [markdown]
# **An image gradient is a directional change in the intensity or color in an image. The gradient of the image is one of the fundamental building blocks in image processing. For example, the Canny edge detector uses image gradient for edge detection. In graphics software for digital image editing, the term gradient or color gradient is also used for a gradual blend of color which can be considered as an even gradation from low to high values, as used from white to black in the images to the right. Another name for this is color progression.**

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('images/fakrul.png', cv.IMREAD_GRAYSCALE)

lap = cv.Laplacian(img, cv.CV_64F, ksize=1)
lap = np.uint8(np.absolute(lap))

sobelX = cv.Sobel(img, cv.CV_64F, 1, 0)
sobelY = cv.Sobel(img, cv.CV_64F, 0, 1)

sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

sobelCombined = cv.bitwise_or(sobelX, sobelY)


titles = ['image', 'lap_gradient', 'sobelX', 'sobelY', 'sobelCombined']
images = [img, lap, sobelX, sobelY, sobelCombined]

cv.imshow('image', img)
cv.imshow('lap_gradient', lap)
cv.imshow('sobelX', sobelX)
cv.imshow('sobelY', sobelY)
cv.imshow('sobelCombined', sobelCombined)


cv.waitKey(0)
cv.destroyAllWindows()

for i in range(5):
    plt.subplot(2, 3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()

# %% [markdown]
# **#  cv.Laplacian(source, data_type, kernel_size)**
# **#  cv.Sobel(img, cv.CV_64F, (dx=order of derivative X), (dy=order of derivative Y), ksize=3)**

# %%
img = cv.imread('images/sudoko.jpg', cv.IMREAD_GRAYSCALE)

lap = cv.Laplacian(img, cv.CV_64F, ksize=1)
lap = np.uint8(np.absolute(lap))

sobelX = cv.Sobel(img, cv.CV_64F, 1, 0)
sobelY = cv.Sobel(img, cv.CV_64F, 0, 1)

sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

sobelCombined = cv.bitwise_or(sobelX, sobelY)


titles = ['image', 'lap_gradient', 'sobelX', 'sobelY', 'sobelCombined']
images = [img, lap, sobelX, sobelY, sobelCombined]

cv.imshow('image', img)
cv.imshow('lap_gradient', lap)
cv.imshow('sobelX', sobelX)
cv.imshow('sobelY', sobelY)
cv.imshow('sobelCombined', sobelCombined)


cv.waitKey(0)
cv.destroyAllWindows()

for i in range(5):
    plt.subplot(2, 3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()
